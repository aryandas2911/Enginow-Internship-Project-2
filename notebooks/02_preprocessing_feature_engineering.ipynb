# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load dataset

# %%
df=pd.read_csv("../data/credit_risk_dataset.csv")

# %%
df.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.59                         Y                           3
# 1                 0.10                         N                           2
# 2                 0.57                         N                           3
# 3                 0.53                         N                           2
# 4                 0.55                         Y                           4

# %% [markdown]
# ## Separate target and feature variables

# %%
X=df.drop("loan_status",axis=1)
y=df["loan_status"]

# %%
X.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_percent_income  \
# 0    PERSONAL          D      35000          16.02                 0.59
# 1   EDUCATION          B       1000          11.14                 0.10
# 2     MEDICAL          C       5500          12.87                 0.57
# 3     MEDICAL          C      35000          15.23                 0.53
# 4     MEDICAL          C      35000          14.27                 0.55
#
#   cb_person_default_on_file  cb_person_cred_hist_length
# 0                         Y                           3
# 1                         N                           2
# 2                         N                           3
# 3                         N                           2
# 4                         Y                           4

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    1
# Name: loan_status, dtype: int64

# %% [markdown]
# ## Numeric vs categorical columns

# %%
num_cols = X.select_dtypes(include=["int64", "float64"]).columns
cat_cols = X.select_dtypes(include=["object"]).columns

# %%
num_cols
# Out:
# Index(['person_age', 'person_income', 'person_emp_length', 'loan_amnt',
#        'loan_int_rate', 'loan_percent_income', 'cb_person_cred_hist_length'],
#       dtype='object')

# %%
cat_cols
# Out:
# Index(['person_home_ownership', 'loan_intent', 'loan_grade',
#        'cb_person_default_on_file'],
#       dtype='object')

# %% [markdown]
# ## Handle missing values

# %%
from sklearn.impute import SimpleImputer

num_imputer= SimpleImputer(strategy="median")
X[num_cols]=num_imputer.fit_transform(X[num_cols])

# %%
X.isnull().sum()
# Out:
# person_age                    0
# person_income                 0
# person_home_ownership         0
# person_emp_length             0
# loan_intent                   0
# loan_grade                    0
# loan_amnt                     0
# loan_int_rate                 0
# loan_percent_income           0
# cb_person_default_on_file     0
# cb_person_cred_hist_length    0
# dtype: int64

# %% [markdown]
# ## Feature Engineering

# %%
X["age_group"] = pd.cut(X["person_age"],bins=[18, 25, 35, 50, 100],labels=["18-25", "26-35", "36-50", "50+"])

# %%
X=X.drop("person_age",axis=1)

# %%
X.head()
# Out:
#    person_income person_home_ownership  person_emp_length loan_intent  \
# 0        59000.0                  RENT              123.0    PERSONAL
# 1         9600.0                   OWN                5.0   EDUCATION
# 2         9600.0              MORTGAGE                1.0     MEDICAL
# 3        65500.0                  RENT                4.0     MEDICAL
# 4        54400.0                  RENT                8.0     MEDICAL
#
#   loan_grade  loan_amnt  loan_int_rate  loan_percent_income  \
# 0          D    35000.0          16.02                 0.59
# 1          B     1000.0          11.14                 0.10
# 2          C     5500.0          12.87                 0.57
# 3          C    35000.0          15.23                 0.53
# 4          C    35000.0          14.27                 0.55
#
#   cb_person_default_on_file  cb_person_cred_hist_length age_group
# 0                         Y                         3.0     18-25
# 1                         N                         2.0     18-25
# 2                         N                         3.0     18-25
# 3                         N                         2.0     18-25
# 4                         Y                         4.0     18-25

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32581 entries, 0 to 32580
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_income               32581 non-null  float64
#  1   person_home_ownership       32581 non-null  object
#  2   person_emp_length           32581 non-null  float64
#  3   loan_intent                 32581 non-null  object
#  4   loan_grade                  32581 non-null  object
#  5   loan_amnt                   32581 non-null  float64
#  6   loan_int_rate               32581 non-null  float64
#  7   loan_percent_income         32581 non-null  float64
#  8   cb_person_default_on_file   32581 non-null  object
#  9   cb_person_cred_hist_length  32581 non-null  float64
#  10  age_group                   32576 non-null  category
# dtypes: category(1), float64(6), object(4)
# memory usage: 2.5+ MB

# %% [markdown]
# ## Encode categorical variables

# %%
X = pd.get_dummies(X, drop_first=True)

# %%
X.head()
# Out:
#    person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 0        59000.0              123.0    35000.0          16.02
# 1         9600.0                5.0     1000.0          11.14
# 2         9600.0                1.0     5500.0          12.87
# 3        65500.0                4.0    35000.0          15.23
# 4        54400.0                8.0    35000.0          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  \
# 0                 0.59                         3.0
# 1                 0.10                         2.0
# 2                 0.57                         3.0
# 3                 0.53                         2.0
# 4                 0.55                         4.0
#
#    person_home_ownership_OTHER  person_home_ownership_OWN  \
# 0                        False                      False
# 1                        False                       True
# 2                        False                      False
# 3                        False                      False
# 4                        False                      False
#
#    person_home_ownership_RENT  loan_intent_EDUCATION  ...  loan_grade_B  \
# 0                        True                  False  ...         False
# 1                       False                   True  ...          True
# 2                       False                  False  ...         False
# 3                        True                  False  ...         False
# 4                        True                  False  ...         False
#
#    loan_grade_C  loan_grade_D  loan_grade_E  loan_grade_F  loan_grade_G  \
# 0         False          True         False         False         False
# 1         False         False         False         False         False
# 2          True         False         False         False         False
# 3          True         False         False         False         False
# 4          True         False         False         False         False
#
#    cb_person_default_on_file_Y  age_group_26-35  age_group_36-50  \
# 0                         True            False            False
# 1                        False            False            False
# 2                        False            False            False
# 3                        False            False            False
# 4                         True            False            False
#
#    age_group_50+
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#
# [5 rows x 24 columns]

# %%
X.shape
# Out:
# (32581, 24)

# %% [markdown]
# ## Scale numerical features

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[-0.11414329, 28.92661352,  4.01940376, ..., -0.8552042 ,
#         -0.32876163, -0.09360637],
#        [-0.91114671,  0.05676262, -1.35864998, ..., -0.8552042 ,
#         -0.32876163, -0.09360637],
#        [-0.91114671, -0.92187639, -0.64684875, ..., -0.8552042 ,
#         -0.32876163, -0.09360637],
#        ...,
#        [ 0.16012914, -0.43255688,  4.01940376, ..., -0.8552042 ,
#         -0.32876163, 10.68303367],
#        [ 1.35402091,  0.05676262,  0.85584274, ..., -0.8552042 ,
#         -0.32876163, 10.68303367],
#        [-0.38841572, -0.67721664, -0.49262515, ..., -0.8552042 ,
#         -0.32876163, 10.68303367]], shape=(32581, 24))

# %% [markdown]
# ## Train-Test split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y,test_size=0.2,stratify=y,random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((26064, 24), (6517, 24))

# %%
y_train.shape, y_test.shape
# Out:
# ((26064,), (6517,))
